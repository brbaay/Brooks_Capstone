# %%
pip install xeus-python -c conda-forge
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'conda-forge'
#
# [notice] A new release of pip available: 22.2 -> 23.2.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages (1.4.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages (from pandas) (1.23.1)
# Requirement already satisfied: six>=1.5 in /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
#
# [notice] A new release of pip available: 22.2 -> 23.2.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 

data = pd.read_csv('Test_134.bedgraph', sep= '\t', names = ['Chrom','Beginning', 'End', 'Coverage'])

print(data.info)
# Out:
# <bound method DataFrame.info of    Chrom  Beginning   End  Coverage
# 0   chrI       2164  2171         8
# 1   chrI       2171  2231         9
# 2   chrI       2231  2235        11
# 3   chrI       2235  2328        12
# 4   chrI       2328  2388        11
# 5   chrI       2388  2389        17
# 6   chrI       2389  2392        18
# 7   chrI       2392  2393        17
# 8   chrI       2393  2396        18
# 9   chrI       2396  2412        19
# 10  chrI       2412  2416        18
# 11  chrI       2416  2417        17
# 12  chrI       2417  2431        10
# 13  chrI       2431  2476         9
# 14  chrI       2476  2606         8
# 15  chrI       2606  2664         7
# 16  chrI       9116  9140         1
# 17  chrI       9140  9143         2
# 18  chrI       9143  9159         3
# 19  chrI       9159  9264         4
# 20  chrI       9639  9707         1>

# %%
def maxCov(cov2,cov1): 
    if cov1 >= cov2: 
        return cov1
    else:
        return cov2

# %%
# column = data.shape[1]
# row = data.shape[0]

# i = 0
# begEnd = [0,0]

# # Parses through the dataframe and finds the beginning and end of a chromosome
# while i != row:

    
#     if begEnd[0] == 0: 
#         begEnd[0] = chromStart
#         begEnd[1] = data.[i,3]
#         i += 1
        
#     while data.iat[i,2] == data.iat[i+1,1]:
#         chromStart = data.iat[i,1]
#         chromEnd = data.iat[i+1,2]
#         begEnd[1] = chromEnd
#         print("poop")
#         i+=1
        
#     promLen = begEnd[1] - begEnd[0]
#     print(begEnd)


      
#     print(i+1)
#     i+=1

# %%
i = 0
k = 0
j = 1
l = 0

 


row = data.shape[0]


myFile = pd.DataFrame(columns=['Promoter Number','Chrom', 'Start', 'Stop', 'Length', 'Avg', 'Med', 'Max Coverage'])
print(myFile)

while i < row+2:
    end = data.iat[i,2]
    start = data.iat[i+1,1]
    # print(end,start,"1")
    cov = 0
    maximum = 0
    mean = 0
    

    while end == start:
        # print(end,start,"2")
        end = data.iat[i,2]
        start = data.iat[i+1,1]
        print(i)
        # i += 1
        # print(end,start,"3")
        i += 1
        newFrame = data.iloc[k:i]
        print(newFrame)
        
        cov = newFrame.loc[i-1, 'Coverage']
        print(cov) 

        maximum = maxCov(maximum, cov)
        print(maximum)
        
        mean += cov
        print(mean)
        
            

            
            
        
    chrom = newFrame.loc[k, 'Chrom']
    print(chrom)
    
    promStart = newFrame.loc[k, 'Beginning']
    promEnd = newFrame.loc[i-1, 'End']
    
    promLen = promEnd - promStart
        
    print(promLen)

    mean = mean/(i - k)
    

    myFile.loc[j, 'Promoter Number'] = j
    myFile.loc[j, 'Chrom'] = chrom
    myFile.loc[j, 'Start'] = promStart
    myFile.loc[j, 'Stop'] = promEnd
    myFile.loc[j, 'Length'] = promLen
    myFile.loc[j, 'Avg'] = mean
    myFile.loc[j, 'Med'] = 0
    myFile.loc[j, 'Max Coverage'] = maximum
    
    print(myFile)
    
    k = i
    j += 1
    cov = 0
    maximum = 0
    mean = 0
# Out:
# Empty DataFrame
# Columns: [Promoter Number, Chrom, Start, Stop, Length, Avg, Med, Max Coverage]
# Index: []
# 0
#   Chrom  Beginning   End  Coverage
# 0  chrI       2164  2171         8
# 8
# 8
# 8
# 1
#   Chrom  Beginning   End  Coverage
# 0  chrI       2164  2171         8
# 1  chrI       2171  2231         9
# 9
# 9
# 17
# 2
#   Chrom  Beginning   End  Coverage
# 0  chrI       2164  2171         8
# 1  chrI       2171  2231         9
# 2  chrI       2231  2235        11
# 11
# 11
# 28
# 3
#   Chrom  Beginning   End  Coverage
# 0  chrI       2164  2171         8
# 1  chrI       2171  2231         9
# 2  chrI       2231  2235        11
# 3  chrI       2235  2328        12
# 12
# 12
# 40
# 4
#   Chrom  Beginning   End  Coverage
# 0  chrI       2164  2171         8
# 1  chrI       2171  2231         9
# 2  chrI       2231  2235        11
# 3  chrI       2235  2328        12
# 4  chrI       2328  2388        11
# 11
# 12
# 51
# 5
#   Chrom  Beginning   End  Coverage
# 0  chrI       2164  2171         8
# 1  chrI       2171  2231         9
# 2  chrI       2231  2235        11
# 3  chrI       2235  2328        12
# 4  chrI       2328  2388        11
# 5  chrI       2388  2389        17
# 17
# 17
# 68
# 6
#   Chrom  Beginning   End  Coverage
# 0  chrI       2164  2171         8
# 1  chrI       2171  2231         9
# 2  chrI       2231  2235        11
# 3  chrI       2235  2328        12
# 4  chrI       2328  2388        11
# 5  chrI       2388  2389        17
# 6  chrI       2389  2392        18
# 18
# 18
# 86
# 7
#   Chrom  Beginning   End  Coverage
# 0  chrI       2164  2171         8
# 1  chrI       2171  2231         9
# 2  chrI       2231  2235        11
# 3  chrI       2235  2328        12
# 4  chrI       2328  2388        11
# 5  chrI       2388  2389        17
# 6  chrI       2389  2392        18
# 7  chrI       2392  2393        17
# 17
# 18
# 103
# 8
#   Chrom  Beginning   End  Coverage
# 0  chrI       2164  2171         8
# 1  chrI       2171  2231         9
# 2  chrI       2231  2235        11
# 3  chrI       2235  2328        12
# 4  chrI       2328  2388        11
# 5  chrI       2388  2389        17
# 6  chrI       2389  2392        18
# 7  chrI       2392  2393        17
# 8  chrI       2393  2396        18
# 18
# 18
# 121
# 9
#   Chrom  Beginning   End  Coverage
# 0  chrI       2164  2171         8
# 1  chrI       2171  2231         9
# 2  chrI       2231  2235        11
# 3  chrI       2235  2328        12
# 4  chrI       2328  2388        11
# 5  chrI       2388  2389        17
# 6  chrI       2389  2392        18
# 7  chrI       2392  2393        17
# 8  chrI       2393  2396        18
# 9  chrI       2396  2412        19
# 19
# 19
# 140
# 10
#    Chrom  Beginning   End  Coverage
# 0   chrI       2164  2171         8
# 1   chrI       2171  2231         9
# 2   chrI       2231  2235        11
# 3   chrI       2235  2328        12
# 4   chrI       2328  2388        11
# 5   chrI       2388  2389        17
# 6   chrI       2389  2392        18
# 7   chrI       2392  2393        17
# 8   chrI       2393  2396        18
# 9   chrI       2396  2412        19
# 10  chrI       2412  2416        18
# 18
# 19
# 158
# 11
#    Chrom  Beginning   End  Coverage
# 0   chrI       2164  2171         8
# 1   chrI       2171  2231         9
# 2   chrI       2231  2235        11
# 3   chrI       2235  2328        12
# 4   chrI       2328  2388        11
# 5   chrI       2388  2389        17
# 6   chrI       2389  2392        18
# 7   chrI       2392  2393        17
# 8   chrI       2393  2396        18
# 9   chrI       2396  2412        19
# 10  chrI       2412  2416        18
# 11  chrI       2416  2417        17
# 17
# 19
# 175
# 12
#    Chrom  Beginning   End  Coverage
# 0   chrI       2164  2171         8
# 1   chrI       2171  2231         9
# 2   chrI       2231  2235        11
# 3   chrI       2235  2328        12
# 4   chrI       2328  2388        11
# 5   chrI       2388  2389        17
# 6   chrI       2389  2392        18
# 7   chrI       2392  2393        17
# 8   chrI       2393  2396        18
# 9   chrI       2396  2412        19
# 10  chrI       2412  2416        18
# 11  chrI       2416  2417        17
# 12  chrI       2417  2431        10
# 10
# 19
# 185
# 13
#    Chrom  Beginning   End  Coverage
# 0   chrI       2164  2171         8
# 1   chrI       2171  2231         9
# 2   chrI       2231  2235        11
# 3   chrI       2235  2328        12
# 4   chrI       2328  2388        11
# 5   chrI       2388  2389        17
# 6   chrI       2389  2392        18
# 7   chrI       2392  2393        17
# 8   chrI       2393  2396        18
# 9   chrI       2396  2412        19
# 10  chrI       2412  2416        18
# 11  chrI       2416  2417        17
# 12  chrI       2417  2431        10
# 13  chrI       2431  2476         9
# 9
# 19
# 194
# 14
#    Chrom  Beginning   End  Coverage
# 0   chrI       2164  2171         8
# 1   chrI       2171  2231         9
# 2   chrI       2231  2235        11
# 3   chrI       2235  2328        12
# 4   chrI       2328  2388        11
# 5   chrI       2388  2389        17
# 6   chrI       2389  2392        18
# 7   chrI       2392  2393        17
# 8   chrI       2393  2396        18
# 9   chrI       2396  2412        19
# 10  chrI       2412  2416        18
# 11  chrI       2416  2417        17
# 12  chrI       2417  2431        10
# 13  chrI       2431  2476         9
# 14  chrI       2476  2606         8
# 8
# 19
# 202
# 15
#    Chrom  Beginning   End  Coverage
# 0   chrI       2164  2171         8
# 1   chrI       2171  2231         9
# 2   chrI       2231  2235        11
# 3   chrI       2235  2328        12
# 4   chrI       2328  2388        11
# 5   chrI       2388  2389        17
# 6   chrI       2389  2392        18
# 7   chrI       2392  2393        17
# 8   chrI       2393  2396        18
# 9   chrI       2396  2412        19
# 10  chrI       2412  2416        18
# 11  chrI       2416  2417        17
# 12  chrI       2417  2431        10
# 13  chrI       2431  2476         9
# 14  chrI       2476  2606         8
# 15  chrI       2606  2664         7
# 7
# 19
# 209
# chrI
# 500
#   Promoter Number Chrom Start  Stop Length      Avg Med Max Coverage
# 1               1  chrI  2164  2664    500  13.0625   0           19
# 16
#    Chrom  Beginning   End  Coverage
# 16  chrI       9116  9140         1
# 1
# 1
# 1
# 17
#    Chrom  Beginning   End  Coverage
# 16  chrI       9116  9140         1
# 17  chrI       9140  9143         2
# 2
# 2
# 3
# 18
#    Chrom  Beginning   End  Coverage
# 16  chrI       9116  9140         1
# 17  chrI       9140  9143         2
# 18  chrI       9143  9159         3
# 3
# 3
# 6
# 19
#    Chrom  Beginning   End  Coverage
# 16  chrI       9116  9140         1
# 17  chrI       9140  9143         2
# 18  chrI       9143  9159         3
# 19  chrI       9159  9264         4
# 4
# 4
# 10
# chrI
# 148
#   Promoter Number Chrom Start  Stop Length      Avg Med Max Coverage
# 1               1  chrI  2164  2664    500  13.0625   0           19
# 2               2  chrI  9116  9264    148      2.5   0            4
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [10], in <cell line: 15>()
#      15 while i < row+2:
#      16     end = data.iat[i,2]
# ---> 17     start = data.iat[i+1,1]
#      18     # print(end,start,"1")
#      19     cov = 0
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/pandas/core/indexing.py:2221, in _ScalarAccessIndexer.__getitem__(self, key)
#    2218         raise ValueError("Invalid call for scalar access (getting)!")
#    2220 key = self._convert_key(key)
# -> 2221 return self.obj._get_value(*key, takeable=self._takeable)
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/pandas/core/frame.py:3613, in DataFrame._get_value(self, index, col, takeable)
#    3611 if takeable:
#    3612     series = self._ixs(col, axis=1)
# -> 3613     return series._values[index]
#    3615 series = self._get_item_cache(col)
#    3616 engine = self.index._engine
#
# IndexError: index 21 is out of bounds for axis 0 with size 21
